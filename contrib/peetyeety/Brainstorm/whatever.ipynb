# %% [markdown]
# # County Market Tracker Data Exploration
#
# Loading and exploring county-level housing market data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("✓ Libraries loaded")
# Out:
# ✓ Libraries loaded

# %%
# Out:
# Loading county_market_tracker.tsv000...
# File size: 363MB, ~563K rows
#
# ✓ Loaded sample: 1000 rows
# ✓ Columns: 58
#
# Column names:
# ...

# %%
# Out:
# Loading full dataset...
#
# ✓ Loaded: 563,122 rows, 58 columns
# ✓ Memory usage: 527.6 MB
#
# Date range: 2012-01-01 to 2021-12-31
# States: 47 unique states
# Counties: 1860 unique counties
# Property types: ['All Residential' 'Multi-Family (2-4 Unit)' 'Condo/Co-op'
#  'Single Family Residential' 'Townhouse']

# %%
# Out:
# SUMMARY STATISTICS:
#
# Key variables:
#        median_sale_price  median_list_price     homes_sold      inventory  \
# count       5.624370e+05       5.192020e+05  562443.000000  540216.000000
# mean        2.048567e+05       2.320302e+05     121.353410     421.794199
# std         1.506078e+06       1.969332e+06     347.492394    1118.946608
# min         1.000000e+00       1.000000e+02       1.000000       1.000000
# 25%         1.150000e+05       1.399000e+05       4.000000      21.000000
# 50%         1.637500e+05       1.899000e+05      18.000000      85.000000
# 75%         2.385000e+05       2.699500e+05      80.000000     331.000000
# max         1.000000e+09       1.000000e+09    9186.000000   26655.000000
#
#        months_of_supply
# count     548158.000000
# mean           5.701756
# std            6.403006
# min            0.000000
# 25%            2.500000
# 50%            4.200000
# 75%            7.000000
# max          874.000000

# %%
# Out:
# Available California counties (sample):
# ['Solano County, CA' 'San Mateo County, CA' 'Butte County, CA'
#  'Alameda County, CA' 'San Diego County, CA' 'Placer County, CA'
#  'Ventura County, CA' 'San Luis Obispo County, CA' 'Santa Cruz County, CA'
#  'Sacramento County, CA' 'Santa Barbara County, CA'
#  'Contra Costa County, CA' 'Stanislaus County, CA' 'San Benito County, CA'
#  'Fresno County, CA' 'Riverside County, CA' 'Yolo County, CA'
#  'Santa Clara County, CA' 'Kern County, CA' 'Yuba County, CA']
#
# ✓ Found 1,200 rows for LA/Orange counties
# Unique county names found:
# ['Orange County, CA' 'Los Angeles County, CA']
#
# ...
# LOS ANGELES AND ORANGE COUNTY DATA
# ...
#
# Shape: (1200, 58)
#
# Date range: 2012-01-01 00:00:00 to 2021-12-31 00:00:00
#
# Property types: ['Condo/Co-op' 'Single Family Residential' 'Multi-Family (2-4 Unit)'
#  'Townhouse' 'All Residential']
#
# ...
# FIRST 20 ROWS:
# ...
#       period_begin                  region       state  \
# ...

# %%
# Out:
# ...
# SUMMARY STATISTICS BY COUNTY
# ...
#
# Orange County, CA:
#   Rows: 600
#   Date range: 2012-01-01 00:00:00 to 2021-12-31 00:00:00
#
#   Key Statistics (excluding NaN):
#     median_sale_price:
#       Mean: $665,883
#       Min: $227,750
#       Max: $1,709,318
#       Non-null values: 600 of 600
#     median_list_price:
#       Mean: $673,802
#       Min: $424,900
#       Max: $922,000
#       Non-null values: 600 of 600
#     homes_sold:
#       Mean: 1,042
#       Min: 4
#       Max: 3,573
#       Non-null values: 600 of 600
#     inventory:
#       Mean: 2,609
#       Min: 9
#       Max: 9,659
#       Non-null values: 600 of 600
#     months_of_supply:
#       Mean: 3
#       Min: 1
#       Max: 12
#       Non-null values: 600 of 600
#     median_ppsf:
#       Mean: $366
#       Min: $191
#       Max: $578
#       Non-null values: 600 of 600
#
#
# Los Angeles County, CA:
#   Rows: 600
#   Date range: 2012-01-01 00:00:00 to 2021-12-31 00:00:00
#
#   Key Statistics (excluding NaN):
# ...

# %%
# Out:
# ...
# DATA PREVIEW - ALL COLUMNS
# ...
#
# Total rows: 1,200
# Total columns: 58
#
# Column names:
#    1. period_begin
#    2. period_end
#    3. period_duration
#    4. region_type
#    5. region_type_id
#    6. table_id
#    7. is_seasonally_adjusted
#    8. region
#    9. city
#   10. state
#   11. state_code
#   12. property_type
#   13. property_type_id
#   14. median_sale_price
#   15. median_sale_price_mom
#   16. median_sale_price_yoy
#   17. median_list_price
#   18. median_list_price_mom
#   19. median_list_price_yoy
#   20. median_ppsf
#   21. median_ppsf_mom
#   22. median_ppsf_yoy
#   23. median_list_ppsf
#   24. median_list_ppsf_mom
#   25. median_list_ppsf_yoy
#   26. homes_sold
#   27. homes_sold_mom
#   28. homes_sold_yoy
#   29. pending_sales
#   30. pending_sales_mom
#   31. pending_sales_yoy
#   32. new_listings
#   33. new_listings_mom
#   34. new_listings_yoy
#   35. inventory
#   36. inventory_mom
#   37. inventory_yoy
#   38. months_of_supply
# ...

# %%
df_filtered.tail()
# Out:
#        period_begin period_end  period_duration region_type  region_type_id  \
# 559061   2017-12-01 2017-12-31               30      county               5
# 559130   2020-03-01 2020-03-31               30      county               5
# 559363   2021-11-01 2021-11-30               30      county               5
# 561176   2012-06-01 2012-06-30               30      county               5
# 562955   2012-10-01 2012-10-31               30      county               5
#
#         table_id is_seasonally_adjusted                  region  city  \
# 559061       332                      f       Orange County, CA   NaN
# 559130       332                      f       Orange County, CA   NaN
# 559363       321                      f  Los Angeles County, CA   NaN
# 561176       321                      f  Los Angeles County, CA   NaN
# 562955       332                      f       Orange County, CA   NaN
#
#              state  ... sold_above_list_yoy price_drops  price_drops_mom  \
# ...
