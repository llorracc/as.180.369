# %% [markdown]
# # Appendix

# %% [markdown]
# ## Appendix A. Additional Figures

# %% [markdown]
# **Figure A.1. Predicted Probability of Offering Advanced STEM Courses by Historic HOLC Grade**
# ![Appendix 1. Predicted Probability of Offering STEM](Figures/Nat_Pred_Prob_OfferingSTEM.png)

# %% [markdown]
# ## Appendix B. Full Regressions with Controls

# %% [markdown]
# **Table B.1. Any STEM - Binary Redline**
#
# | term              | Coef (SE)      | p       |
# |:------------------|:---------------|:--------|
# | Intercept         | 0.771 (0.173)  | < .001  |
# | Redline_CD        | -0.105 (0.054) | 0.051   |
# | MAGNET_FLAG       | 0.218 (0.064)  | < .001  |
# | CHARTER_FLAG      | -0.080 (0.079) | 0.314   |
# | PCT_CERTIFIED_FTE | -0.000 (0.002) | 0.878   |
# | TITLE1_FLAG       | 0.147 (0.056)  | 0.009** |
#
#
# **Table B.2. Any STEM - Grade Categories**
#
# | term                              | Coef (SE)      | p       |
# |:----------------------------------|:---------------|:--------|
# | Intercept                         | 0.783 (0.194)  | < .001  |
# | C(grade_cat, Treatment('A'))[T.B] | 0.010 (0.095)  | 0.915   |
# | C(grade_cat, Treatment('A'))[T.C] | -0.052 (0.088) | 0.554   |
# | C(grade_cat, Treatment('A'))[T.D] | -0.152 (0.099) | 0.124   |
# | MAGNET_FLAG                       | 0.238 (0.064)  | < .001  |
# | CHARTER_FLAG                      | -0.061 (0.081) | 0.449   |
# | PCT_CERTIFIED_FTE                 | -0.001 (0.002) | 0.778   |
# | TITLE1_FLAG                       | 0.146 (0.057)  | 0.010** |
#
#
# **Table B.3. Total STEM Classes - Binary Redline**
#
# | term              | Coef (SE)       | p       |
# |:------------------|:----------------|:--------|
# | Intercept         | 23.512 (8.454)  | 0.005** |
# | Redline_CD        | -6.675 (2.290)  | 0.004** |
# | MAGNET_FLAG       | 3.267 (3.480)   | 0.348   |
# | CHARTER_FLAG      | -11.718 (2.998) | < .001  |
# | PCT_CERTIFIED_FTE | -0.057 (0.086)  | 0.510   |
# | TITLE1_FLAG       | 5.475 (2.734)   | 0.045*  |
#
#
# **Table B.4. Total STEM Classes - Grade Categories**
#
# | term                              | Coef (SE)       | p       |
# |:----------------------------------|:----------------|:--------|
# | Intercept                         | 26.984 (9.246)  | 0.004** |
# | C(grade_cat, Treatment('A'))[T.B] | -3.124 (3.462)  | 0.367   |
# | C(grade_cat, Treatment('A'))[T.C] | -5.874 (3.557)  | 0.099   |
# | C(grade_cat, Treatment('A'))[T.D] | -12.474 (3.663) | < .001  |
# | MAGNET_FLAG                       | 4.644 (3.505)   | 0.185   |
# | CHARTER_FLAG                      | -10.758 (2.989) | < .001  |
# | PCT_CERTIFIED_FTE                 | -0.072 (0.088)  | 0.413   |
# | TITLE1_FLAG                       | 5.794 (2.713)   | 0.033*  |
