# %% [markdown]
# # National

# %% [markdown]
# ## Regression

# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# =====================================================
# 1. FILES & BASE DATA
# =====================================================

analysis_file = "National_Schools_with_AdvancedSTEM_Expanded.csv"
school_chars_file = "school chars.csv"    # same file you used earlier

# Load analysis dataset
df = pd.read_csv(analysis_file, dtype=str)
df["NCESSCH"] = df["NCESSCH"].astype(str)

print("Loaded analysis data:", df.shape)

# -----------------------------------------------------
# 2. MERGE STATE & DISTRICT INFO (ST / LEAID)
# -----------------------------------------------------

sch_chars = pd.read_csv(school_chars_file, dtype=str)
if "NCESSCH" not in sch_chars.columns:
    raise ValueError("Expected NCESSCH column in school chars.csv")

sch_chars["NCESSCH"] = sch_chars["NCESSCH"].astype(str)

# Pick state column
if "ST" in sch_chars.columns:
    state_col = "ST"
elif "STATENAME" in sch_chars.columns:
    state_col = "STATENAME"
else:
    raise ValueError("Expected ST or STATENAME in school chars.csv")

if "LEAID" not in sch_chars.columns:
    raise ValueError("Expected LEAID in school chars.csv")

sch_chars_small = sch_chars[["NCESSCH", state_col, "LEAID"]].drop_duplicates("NCESSCH")

df = df.merge(sch_chars_small, on="NCESSCH", how="left")
df.rename(columns={state_col: "ST"}, inplace=True)

print("After merging ST and LEAID:", df.shape)

# =====================================================
# 3. CONSTRUCT KEY VARIABLES
# =====================================================

# --- HOLC treatment variables ---
df["grade"] = df["grade"].astype(str).str.strip().str.upper()
df["Redline_CD"] = df["grade"].isin(["C", "D"]).astype(int)
df["grade_cat"] = pd.Categorical(df["grade"], categories=["A", "B", "C", "D"])

# --- STEM outcomes ---

# Make sure Has_* exist
for col in ["Has_Calc", "Has_CS", "Has_Physics"]:
    if col not in df.columns:
        df[col] = "No"

df["Any_STEM"] = (
    (df["Has_Calc"] == "Yes") |
    (df["Has_CS"] == "Yes") |
    (df["Has_Physics"] == "Yes")
).astype(int)

for col in ["Num_Calc_Classes", "Num_CS_Classes", "Num_Physics_Classes"]:
    if col not in df.columns:
        df[col] = 0
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0)

df["Total_STEM_Classes"] = (
    df["Num_Calc_Classes"] +
    df["Num_CS_Classes"] +
    df["Num_Physics_Classes"]
)

# --- Control variables ---

# Separate magnet + charter flags from status columns
for status_col in ["SCH_STATUS_MAGNET", "SCH_STATUS_CHARTER"]:
    if status_col not in df.columns:
        df[status_col] = np.nan

def status_to_flag(series):
    pos = {"YES", "Y", "1", "TRUE", "T"}
    return series.astype(str).str.strip().str.upper().isin(pos).astype(int)

df["MAGNET_FLAG"] = status_to_flag(df["SCH_STATUS_MAGNET"])
df["CHARTER_FLAG"] = status_to_flag(df["SCH_STATUS_CHARTER"])

# PCT_CERTIFIED_FTE numeric
if "PCT_CERTIFIED_FTE" not in df.columns:
    df["PCT_CERTIFIED_FTE"] = np.nan
df["PCT_CERTIFIED_FTE"] = pd.to_numeric(df["PCT_CERTIFIED_FTE"], errors="coerce")

# TITLE1_FLAG numeric
if "TITLE1_FLAG" not in df.columns:
    df["TITLE1_FLAG"] = np.nan
df["TITLE1_FLAG"] = pd.to_numeric(df["TITLE1_FLAG"], errors="coerce")

# Ensure ST and LEAID are strings (for fixed effects & clustering)
df["ST"] = df["ST"].astype(str)
df["LEAID"] = df["LEAID"].astype(str)

# =====================================================
# 4. REGRESSION SAMPLE
# =====================================================

needed_cols = [
    "Any_STEM", "Total_STEM_Classes",
    "Redline_CD", "grade_cat",
    "MAGNET_FLAG", "CHARTER_FLAG",
    "PCT_CERTIFIED_FTE", "TITLE1_FLAG",
    "ST", "LEAID"
]

reg_df = df[needed_cols].copy()

# Drop rows with missing in key vars
reg_df = reg_df.dropna(
    subset=[
        "Any_STEM",
        "Total_STEM_Classes",
        "PCT_CERTIFIED_FTE",
        "TITLE1_FLAG",
        "ST",
        "LEAID",
        "grade_cat"
    ]
)

# Coerce numeric types
reg_df["Any_STEM"] = reg_df["Any_STEM"].astype(int)
reg_df["Total_STEM_Classes"] = pd.to_numeric(
    reg_df["Total_STEM_Classes"], errors="coerce"
).fillna(0)

reg_df["Redline_CD"] = reg_df["Redline_CD"].astype(int)
reg_df["MAGNET_FLAG"] = reg_df["MAGNET_FLAG"].astype(int)
reg_df["CHARTER_FLAG"] = reg_df["CHARTER_FLAG"].astype(int)
reg_df["TITLE1_FLAG"] = reg_df["TITLE1_FLAG"].astype(float)

print("Final regression sample:", reg_df.shape)

# =====================================================
# 5. HELPER: OLS WITH CLUSTERED SE BY LEAID
# =====================================================

def fit_ols_cluster(formula, data, cluster_var, model_name):
    model = smf.ols(formula, data=data)
    res = model.fit(
        cov_type="cluster",
        cov_kwds={"groups": data[cluster_var]}
    )
    params = res.params
    bse = res.bse
    pvals = res.pvalues
    tvals = res.tvalues

    out = pd.DataFrame({
        "term": params.index,
        "coef": params.values,
        "std_err": bse.values,
        "t_value": tvals.values,
        "p_value": pvals.values,
        "model": model_name
    })
    return res, out

results_list = []

# =====================================================
# 6. LPM MODELS (OLS) — Any_STEM
# =====================================================

# (1) Any_STEM ~ Redline_CD + controls + state & district FE
formula_lpm_bin = """
Any_STEM ~ Redline_CD
           + MAGNET_FLAG
           + CHARTER_FLAG
           + PCT_CERTIFIED_FTE
           + TITLE1_FLAG
           
"""

lpm_bin_res, lpm_bin_tidy = fit_ols_cluster(
    formula_lpm_bin,
    data=reg_df,
    cluster_var="LEAID",
    model_name="LPM_AnySTEM_BinaryRedline"
)
results_list.append(lpm_bin_tidy)
print("\n=== LPM: Any_STEM ~ Redline_CD + controls + ST & LEAID FE ===")
print(lpm_bin_res.summary())

# (2) Any_STEM ~ full HOLC grade dummies + controls + FE
formula_lpm_cat = """
Any_STEM ~ C(grade_cat, Treatment('A'))
           + MAGNET_FLAG
           + CHARTER_FLAG
           + PCT_CERTIFIED_FTE
           + TITLE1_FLAG
           
"""

lpm_cat_res, lpm_cat_tidy = fit_ols_cluster(
    formula_lpm_cat,
    data=reg_df,
    cluster_var="LEAID",
    model_name="LPM_AnySTEM_GradeCat"
)
results_list.append(lpm_cat_tidy)
print("\n=== LPM: Any_STEM ~ HOLC grade dummies + controls + ST & LEAID FE ===")
print(lpm_cat_res.summary())

# =====================================================
# 7. LPM MODELS (OLS) — Total_STEM_Classes
# =====================================================

# (3) Total_STEM_Classes ~ Redline_CD + controls + FE
formula_lpm_tot_bin = """
Total_STEM_Classes ~ Redline_CD
                     + MAGNET_FLAG
                     + CHARTER_FLAG
                     + PCT_CERTIFIED_FTE
                     + TITLE1_FLAG
                     
"""

lpm_tot_bin_res, lpm_tot_bin_tidy = fit_ols_cluster(
    formula_lpm_tot_bin,
    data=reg_df,
    cluster_var="LEAID",
    model_name="LPM_TotalSTEM_BinaryRedline"
)
results_list.append(lpm_tot_bin_tidy)
print("\n=== LPM: Total_STEM_Classes ~ Redline_CD + controls + ST & LEAID FE ===")
print(lpm_tot_bin_res.summary())

# (4) Total_STEM_Classes ~ full HOLC grade dummies + controls + FE
formula_lpm_tot_cat = """
Total_STEM_Classes ~ C(grade_cat, Treatment('A'))
                     + MAGNET_FLAG
                     + CHARTER_FLAG
                     + PCT_CERTIFIED_FTE
                     + TITLE1_FLAG
                     
"""

lpm_tot_cat_res, lpm_tot_cat_tidy = fit_ols_cluster(
    formula_lpm_tot_cat,
    data=reg_df,
    cluster_var="LEAID",
    model_name="LPM_TotalSTEM_GradeCat"
)
results_list.append(lpm_tot_cat_tidy)
print("\n=== LPM: Total_STEM_Classes ~ HOLC grade dummies + controls + ST & LEAID FE ===")
print(lpm_tot_cat_res.summary())

# =====================================================
# 8. EXPORT TIDY RESULTS
# =====================================================

all_results = pd.concat(results_list, ignore_index=True)
out_csv = "Regression_Results_LPM.csv"
all_results.to_csv(out_csv, index=False)

print("\nSaved LPM regression results to:", os.path.abspath(out_csv))
# Out:
# Loaded analysis data: (1767, 19)
# After merging ST and LEAID: (1767, 21)
# Final regression sample: (377, 10)
#
# === LPM: Any_STEM ~ Redline_CD + controls + ST & LEAID FE ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     3.869
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):            0.00212
# Time:                        15:55:49   Log-Likelihood:                -227.09
# No. Observations:                 377   AIC:                             466.2
# Df Residuals:                     371   BIC:                             489.8
# Df Model:                           5
# Covariance Type:              cluster
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.7715      0.173      4.456      0.000       0.432       1.111
# Redline_CD           -0.1055      0.054     -1.951      0.051      -0.211       0.000
# MAGNET_FLAG           0.2180      0.064      3.401      0.001       0.092       0.344
# CHARTER_FLAG         -0.0799      0.079     -1.006      0.314      -0.236       0.076
# PCT_CERTIFIED_FTE    -0.0003      0.002     -0.154      0.878      -0.004       0.003
# TITLE1_FLAG           0.1465      0.056      2.606      0.009       0.036       0.257
# ==============================================================================
# Omnibus:                      137.201   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.811
# Skew:                          -0.865   Prob(JB):                     8.44e-15
# Kurtosis:                       1.936   Cond. No.                         648.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === LPM: Any_STEM ~ HOLC grade dummies + controls + ST & LEAID FE ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     3.253
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):            0.00250
# Time:                        15:55:49   Log-Likelihood:                -225.52
# No. Observations:                 377   AIC:                             467.0
# Df Residuals:                     369   BIC:                             498.5
# Df Model:                           7
# Covariance Type:              cluster
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.7829      0.194      4.041      0.000       0.403       1.163
# C(grade_cat, Treatment('A'))[T.B]     0.0101      0.095      0.107      0.915      -0.176       0.196
# C(grade_cat, Treatment('A'))[T.C]    -0.0521      0.088     -0.591      0.554      -0.225       0.121
# C(grade_cat, Treatment('A'))[T.D]    -0.1519      0.099     -1.537      0.124      -0.346       0.042
# MAGNET_FLAG                           0.2380      0.064      3.740      0.000       0.113       0.363
# CHARTER_FLAG                         -0.0613      0.081     -0.757      0.449      -0.220       0.097
# PCT_CERTIFIED_FTE                    -0.0005      0.002     -0.282      0.778      -0.004       0.003
# TITLE1_FLAG                           0.1462      0.057      2.581      0.010       0.035       0.257
# ==============================================================================
# Omnibus:                      128.960   Durbin-Watson:                   1.779
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.960
# Skew:                          -0.853   Prob(JB):                     2.13e-14
# Kurtosis:                       1.951   Cond. No.                         787.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === LPM: Total_STEM_Classes ~ Redline_CD + controls + ST & LEAID FE ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     8.637
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           1.35e-07
# Time:                        15:55:49   Log-Likelihood:                -1621.4
# No. Observations:                 377   AIC:                             3255.
# Df Residuals:                     371   BIC:                             3278.
# Df Model:                           5
# Covariance Type:              cluster
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            23.5115      8.454      2.781      0.005       6.942      40.081
# Redline_CD           -6.6749      2.290     -2.915      0.004     -11.163      -2.187
# MAGNET_FLAG           3.2672      3.480      0.939      0.348      -3.553      10.087
# CHARTER_FLAG        -11.7176      2.998     -3.909      0.000     -17.593      -5.842
# PCT_CERTIFIED_FTE    -0.0568      0.086     -0.659      0.510      -0.226       0.112
# TITLE1_FLAG           5.4755      2.734      2.003      0.045       0.117      10.834
# ==============================================================================
# Omnibus:                      154.157   Durbin-Watson:                   1.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              505.773
# Skew:                           1.897   Prob(JB):                    1.49e-110
# Kurtosis:                       7.219   Cond. No.                         648.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# === LPM: Total_STEM_Classes ~ HOLC grade dummies + controls + ST & LEAID FE ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     7.575
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           2.51e-08
# Time:                        15:55:49   Log-Likelihood:                -1616.8
# No. Observations:                 377   AIC:                             3250.
# Df Residuals:                     369   BIC:                             3281.
# Df Model:                           7
# Covariance Type:              cluster
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            26.9838      9.246      2.918      0.004       8.861      45.106
# C(grade_cat, Treatment('A'))[T.B]    -3.1237      3.462     -0.902      0.367      -9.908       3.661
# C(grade_cat, Treatment('A'))[T.C]    -5.8739      3.557     -1.652      0.099     -12.845       1.097
# C(grade_cat, Treatment('A'))[T.D]   -12.4743      3.663     -3.406      0.001     -19.653      -5.295
# MAGNET_FLAG                           4.6436      3.505      1.325      0.185      -2.225      11.513
# CHARTER_FLAG                        -10.7577      2.989     -3.599      0.000     -16.616      -4.899
# PCT_CERTIFIED_FTE                    -0.0725      0.088     -0.819      0.413      -0.246       0.101
# TITLE1_FLAG                           5.7936      2.713      2.136      0.033       0.477      11.110
# ==============================================================================
# Omnibus:                      149.563   Durbin-Watson:                   1.341
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              480.367
# Skew:                           1.843   Prob(JB):                    4.89e-105
# Kurtosis:                       7.123   Cond. No.                         787.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# Saved LPM regression results to: /Users/zoechan/Documents/GitHub/as.180.369/contrib/zoemchan/zoemchan-prelim-paper/paper/data/Regression_Results_LPM.csv

# %%
import pandas as pd
import numpy as np
import os

# ===== Load your regression results from earlier =====
df = pd.read_csv("Regression_Results_LPM.csv")  # change filename if needed

# ===== APA formatting helpers =====
def format_p(p):
    if p < 0.001:
        return "< .001"
    elif p < 0.01:
        return f"{p:.3f}**"
    elif p < 0.05:
        return f"{p:.3f}*"
    else:
        return f"{p:.3f}"

def format_coef(coef, se):
    return f"{coef:.3f} ({se:.3f})"

# ===== Create output directory for APA tables =====
out_dir = "apa_tables"
os.makedirs(out_dir, exist_ok=True)

apa_tables = {}

for model in df['model'].unique():
    sub = df[df['model'] == model].copy()

    # Create APA columns
    sub["Coef (SE)"] = [
        format_coef(c, s) for c, s in zip(sub["coef"], sub["std_err"])
    ]
    sub["p"] = sub["p_value"].apply(format_p)

    # Select clean APA-style columns
    apa = sub[["term", "Coef (SE)", "p"]]

    # Save CSV
    csv_path = os.path.join(out_dir, f"APA_{model}.csv")
    apa.to_csv(csv_path, index=False)

    # Save Markdown version (great for your paper)
    md_path = os.path.join(out_dir, f"APA_{model}.md")
    apa.to_markdown(md_path, index=False)

    print(f"Saved APA table for {model} → {csv_path}")

print("\nAll APA tables saved in folder:", os.path.abspath(out_dir))
# Out:
# Saved APA table for LPM_AnySTEM_BinaryRedline → apa_tables/APA_LPM_AnySTEM_BinaryRedline.csv
# Saved APA table for LPM_AnySTEM_GradeCat → apa_tables/APA_LPM_AnySTEM_GradeCat.csv
# Saved APA table for LPM_TotalSTEM_BinaryRedline → apa_tables/APA_LPM_TotalSTEM_BinaryRedline.csv
# Saved APA table for LPM_TotalSTEM_GradeCat → apa_tables/APA_LPM_TotalSTEM_GradeCat.csv
#
# All APA tables saved in folder: /Users/zoechan/Documents/GitHub/as.180.369/contrib/zoemchan/zoemchan-prelim-paper/paper/data/apa_tables

# %% [markdown]
# ## Visuals

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

df = pd.read_csv("National_Schools_with_AdvancedSTEM_Expanded.csv")

# --------------------------------------------------------
# Improved binary conversion
# --------------------------------------------------------
def to_binary(x):
    x = str(x).strip().lower()
    if x in ["yes", "y", "1", "1.0", "true", "t"]:
        return 1
    elif x in ["no", "n", "0", "0.0", "false", "f"]:
        return 0
    return np.nan

# Convert Has_* fields
for col in ["Has_Calc", "Has_CS", "Has_Physics"]:
    df[col] = df[col].apply(to_binary)

# Any STEM outcome
df["Any_STEM"] = (
    (df["Has_Calc"] == 1) |
    (df["Has_CS"] == 1) |
    (df["Has_Physics"] == 1)
).astype(int)

# Keep valid grades
df = df[df["grade"].isin(["A","B","C","D"])]

# Numeric grade
grade_map = {"A":1, "B":2, "C":3, "D":4}
df["grade_num"] = df["grade"].map(grade_map)

# --------------------------------------------------------
# Fix TITLE1_FLAG (replace missing with 0, then convert)
# --------------------------------------------------------
df["TITLE1_FLAG"] = df["TITLE1_FLAG"].fillna(0)
df["TITLE1_FLAG"] = df["TITLE1_FLAG"].apply(to_binary)

# --------------------------------------------------------
# Clean charter/magnet columns
# --------------------------------------------------------
df["SCH_STATUS_CHARTER"] = df["SCH_STATUS_CHARTER"].apply(to_binary)
df["SCH_STATUS_MAGNET"]  = df["SCH_STATUS_MAGNET"].apply(to_binary)

# --------------------------------------------------------
# Clean % certified (numeric, fill missing with mean)
# --------------------------------------------------------
df["PCT_CERTIFIED_FTE"] = pd.to_numeric(df["PCT_CERTIFIED_FTE"], errors="coerce")
df["PCT_CERTIFIED_FTE"] = df["PCT_CERTIFIED_FTE"].fillna(df["PCT_CERTIFIED_FTE"].mean())

# --------------------------------------------------------
# Build matrix X
# --------------------------------------------------------
X = df[[
    "grade_num",
    "TITLE1_FLAG",
    "SCH_STATUS_CHARTER",
    "SCH_STATUS_MAGNET",
    "PCT_CERTIFIED_FTE"
]].copy()

# Ensure numeric
X = X.apply(pd.to_numeric, errors="coerce")

# Add constant
X = sm.add_constant(X)

# Outcome
y = df["Any_STEM"].astype(float)

# --------------------------------------------------------
# Check for any NaNs left
# --------------------------------------------------------
print("NaNs per column:\n", X.isna().sum())
print("Rows with NaNs:", X.isna().any(axis=1).sum())

# Drop remaining NaNs (should now be very few or zero)
mask = ~X.isna().any(axis=1)
X = X[mask]
y = y[mask]

# --------------------------------------------------------
# Fit logistic regression
# --------------------------------------------------------
logit_model = sm.Logit(y, X)
logit_res = logit_model.fit()
print(logit_res.summary())

# --------------------------------------------------------
# Predicted probabilities for grades A-D
# --------------------------------------------------------
grades = [1, 2, 3, 4]
labels = ["A", "B", "C", "D"]
pred_probs = []

mean_vals = X.mean()

for g in grades:
    row = mean_vals.copy()
    row["grade_num"] = g
    pred_probs.append(float(logit_res.predict(row)))

plt.figure(figsize=(8,6))
plt.plot(labels, pred_probs, marker="o", linewidth=3)
plt.xlabel("HOLC Grade")
plt.ylabel("Predicted Probability of Offering Any Advanced STEM Course")
plt.title("Predicted Probability of STEM Access by HOLC Grade")
plt.ylim(0, 1)
plt.grid(False)
plt.show()
# Out:
# NaNs per column:
#  const                 0
# grade_num             0
# TITLE1_FLAG           0
# SCH_STATUS_CHARTER    0
# SCH_STATUS_MAGNET     0
# PCT_CERTIFIED_FTE     0
# dtype: int64
# Rows with NaNs: 0
# Optimization terminated successfully.
#          Current function value: 0.548240
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   No. Observations:                 1767
# Model:                          Logit   Df Residuals:                     1761
# Method:                           MLE   Df Model:                            5
# Date:                Mon, 17 Nov 2025   Pseudo R-squ.:                 0.01655
# Time:                        00:54:52   Log-Likelihood:                -968.74
# converged:                       True   LL-Null:                       -985.04
# Covariance Type:            nonrobust   LLR p-value:                 4.518e-06
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  1.4988      0.411      3.651      0.000       0.694       2.303
# grade_num             -0.1225      0.068     -1.790      0.073      -0.257       0.012
# TITLE1_FLAG            0.2955      0.280      1.054      0.292      -0.254       0.845
# SCH_STATUS_CHARTER    -0.0340      0.135     -0.252      0.801      -0.299       0.230
# SCH_STATUS_MAGNET      1.1609      0.251      4.617      0.000       0.668       1.654
# PCT_CERTIFIED_FTE     -0.0010      0.003     -0.291      0.771      -0.008       0.006
# ======================================================================================
# /var/folders/hz/d49rtbh904s9fy8xy2xyj8m40000gn/T/ipykernel_1128/2935010901.py:105: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pred_probs.append(float(logit_res.predict(row)))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ======================
# Load national dataset
# ======================
df = pd.read_csv("National_Schools_with_AdvancedSTEM.csv")

# Ensure categorical order A → D
df["grade"] = pd.Categorical(df["grade"], categories=["A","B","C","D"], ordered=True)

# Melt dataframe for seaborn barplot
subjects = ["Num_Calc_Classes", "Num_CS_Classes", "Num_Physics_Classes"]

plot_df = df.melt(
    id_vars="grade",
    value_vars=subjects,
    var_name="Subject",
    value_name="Classes"
)

# ======================
# Plot
# ======================
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))

sns.barplot(
    data=plot_df,
    x="grade",
    y="Classes",
    hue="Subject",
    estimator=np.mean,
    errorbar="se"
)

plt.title("National Average Number of Advanced STEM Classes by HOLC Grade", fontsize=15, fontweight="bold")
plt.xlabel("HOLC Grade", fontsize=12)
plt.ylabel("Average Number of Classes", fontsize=12)

# Consistent y-limit with city charts
plt.ylim(0, 10)

plt.legend(title="Subject")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## LA Regressions

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# =========================
# 1. LOAD DATA
# =========================

# LA schools that are in HOLC buffers
la_file = "LA_Schools_with_AdvancedSTEM.csv"
la_schools = pd.read_csv(la_file, dtype=str)

# National dataset with controls + STEM + Title I etc.
nat_file = "National_Schools_with_AdvancedSTEM_Expanded.csv"
nat = pd.read_csv(nat_file, dtype=str)

# Ensure NCESSCH exists
la_schools["NCESSCH"] = la_schools["NCESSCH"].astype(str)
nat["NCESSCH"] = nat["NCESSCH"].astype(str)

# =========================
# 2. MERGE LA LIST → NATIONAL DATA
# =========================

la_ids = la_schools[["NCESSCH"]].drop_duplicates()
df = la_ids.merge(nat, on="NCESSCH", how="left")

print(f"LA matched schools: {len(df)}")

# =========================
# 3. CLEAN VARIABLES
# =========================

# HOLC GRADE
df["grade"] = df["grade"].astype(str).str.strip().str.upper()
valid_grades = ["A", "B", "C", "D"]

df = df[df["grade"].isin(valid_grades)].copy()
df["grade_cat"] = pd.Categorical(df["grade"], categories=["A", "B", "C", "D"], ordered=True)

# BINARY REDLINE: A/B = 0, C/D = 1
df["Redline_CD"] = df["grade"].isin(["C", "D"]).astype(int)

# STEM COUNTS
for col in ["Num_Calc_Classes", "Num_CS_Classes", "Num_Physics_Classes"]:
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

# STEM INDICATORS
for subj, cnt in [
    ("Has_Calc", "Num_Calc_Classes"),
    ("Has_CS", "Num_CS_Classes"),
    ("Has_Physics", "Num_Physics_Classes"),
]:
    df[subj] = df[subj].fillna("No")
    df[subj + "_bin"] = df[subj].map({"Yes": 1, "No": 0})

# OUTCOME: Any STEM offered
df["Any_STEM"] = (
    df["Has_Calc_bin"] | df["Has_CS_bin"] | df["Has_Physics_bin"]
).astype(int)

# OUTCOME: Total STEM classes
df["Total_STEM_Classes"] = (
    df["Num_Calc_Classes"] + df["Num_CS_Classes"] + df["Num_Physics_Classes"]
)

# CONTROLS
def make_flag(col):
    return col.astype(str).str.strip().str.upper().map(
        {"YES": 1, "NO": 0, "1": 1, "0": 0}
    ).fillna(0).astype(int)

if "MAGNET_FLAG" in df.columns:
    df["MAGNET_FLAG"] = make_flag(df["MAGNET_FLAG"])
else:
    df["MAGNET_FLAG"] = 0

if "CHARTER_FLAG" in df.columns:
    df["CHARTER_FLAG"] = make_flag(df["CHARTER_FLAG"])
else:
    df["CHARTER_FLAG"] = 0

if "TITLE1_FLAG" in df.columns:
    df["TITLE1_FLAG"] = make_flag(df["TITLE1_FLAG"])
else:
    df["TITLE1_FLAG"] = 0

df["PCT_CERTIFIED_FTE"] = pd.to_numeric(df["PCT_CERTIFIED_FTE"], errors="coerce")

reg_df = df.dropna(subset=["Any_STEM", "Total_STEM_Classes", "Redline_CD"])

print("Final LA sample:", len(reg_df))

# =========================
# 4. HELPER FUNCTION: OLS LPM WITH HC3 ROBUST SE
# =========================

def run_lpm(formula, data, name):
    model = smf.ols(formula, data=data)
    res = model.fit(cov_type="HC3")  # HC3 robust SE
    tidy = pd.DataFrame({
        "term": res.params.index,
        "coef": res.params.values,
        "std_err": res.bse.values,
        "t_value": res.tvalues.values,
        "p_value": res.pvalues.values,
        "model": name
    })
    print(f"\n===== {name} =====")
    print(res.summary())
    return res, tidy

results = []

# =========================
# 5. RUN LA REGRESSIONS (NO CLUSTERING)
# =========================

# 5.1 Any STEM (binary) using Redline_CD
formula1 = """
Any_STEM ~ Redline_CD
           + MAGNET_FLAG
           + CHARTER_FLAG
           + PCT_CERTIFIED_FTE
           + TITLE1_FLAG
"""
res1, tidy1 = run_lpm(formula1, reg_df, "LA_LPM_AnySTEM_BinaryRedline")
results.append(tidy1)

# 5.2 Any STEM using categorical HOLC grade
formula2 = """
Any_STEM ~ C(grade_cat, Treatment('A'))
           + MAGNET_FLAG
           + CHARTER_FLAG
           + PCT_CERTIFIED_FTE
           + TITLE1_FLAG
"""
res2, tidy2 = run_lpm(formula2, reg_df, "LA_LPM_AnySTEM_GradeCat")
results.append(tidy2)

# 5.3 Total STEM using Redline_CD
formula3 = """
Total_STEM_Classes ~ Redline_CD
                     + MAGNET_FLAG
                     + CHARTER_FLAG
                     + PCT_CERTIFIED_FTE
                     + TITLE1_FLAG
"""
res3, tidy3 = run_lpm(formula3, reg_df, "LA_LPM_TotalSTEM_BinaryRedline")
results.append(tidy3)

# 5.4 Total STEM using categorical HOLC grade
formula4 = """
Total_STEM_Classes ~ C(grade_cat, Treatment('A'))
                     + MAGNET_FLAG
                     + CHARTER_FLAG
                     + PCT_CERTIFIED_FTE
                     + TITLE1_FLAG
"""
res4, tidy4 = run_lpm(formula4, reg_df, "LA_LPM_TotalSTEM_GradeCat")
results.append(tidy4)

# =========================
# 6. SAVE COMBINED RESULTS
# =========================

la_results = pd.concat(results, ignore_index=True)
la_results.to_csv("LA_Regression_Results_LPM.csv", index=False)
print("\nSaved → LA_Regression_Results_LPM.csv")
# Out:
# LA matched schools: 163
# Final LA sample: 163
#
# ===== LA_LPM_AnySTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.5091
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.602
# Time:                        17:43:05   Log-Likelihood:                -94.514
# No. Observations:                 163   AIC:                             195.0
# Df Residuals:                     160   BIC:                             204.3
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.0059      0.455      2.210      0.027       0.114       1.898
# Redline_CD            0.0788      0.135      0.584      0.559      -0.186       0.343
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE    -0.0034      0.004     -0.771      0.441      -0.012       0.005
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       31.991   Durbin-Watson:                   1.745
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.001
# Skew:                          -1.134   Prob(JB):                     5.60e-09
# Kurtosis:                       2.328   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== LA_LPM_AnySTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.5104
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.728
# Time:                        17:43:05   Log-Likelihood:                -93.626
# No. Observations:                 163   AIC:                             197.3
# Df Residuals:                     158   BIC:                             212.7
# Df Model:                           4
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.8568      0.848      1.010      0.312      -0.805       2.519
# C(grade_cat, Treatment('A'))[T.B]     0.1868      0.720      0.259      0.795      -1.225       1.599
# C(grade_cat, Treatment('A'))[T.C]     0.2020      0.709      0.285      0.776      -1.188       1.592
# C(grade_cat, Treatment('A'))[T.D]     0.2879      0.709      0.406      0.685      -1.102       1.677
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                    -0.0036      0.005     -0.762      0.446      -0.013       0.006
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       30.733   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.899
# Skew:                          -1.120   Prob(JB):                     9.72e-09
# Kurtosis:                       2.357   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== LA_LPM_TotalSTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                     1.294
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.277
# Time:                        17:43:05   Log-Likelihood:                -619.04
# No. Observations:                 163   AIC:                             1244.
# Df Residuals:                     160   BIC:                             1253.
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -3.1624      7.100     -0.445      0.656     -17.077      10.753
# Redline_CD            2.4246      1.681      1.442      0.149      -0.870       5.719
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE     0.0807      0.071      1.140      0.254      -0.058       0.219
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      215.117   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12138.774
# Skew:                           5.290   Prob(JB):                         0.00
# Kurtosis:                      43.932   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== LA_LPM_TotalSTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.6344
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.639
# Time:                        17:43:05   Log-Likelihood:                -618.94
# No. Observations:                 163   AIC:                             1248.
# Df Residuals:                     158   BIC:                             1263.
# Df Model:                           4
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -3.4234      9.437     -0.363      0.717     -21.920      15.074
# C(grade_cat, Treatment('A'))[T.B]     0.4680      6.529      0.072      0.943     -12.328      13.264
# C(grade_cat, Treatment('A'))[T.C]     2.4746      6.448      0.384      0.701     -10.164      15.113
# C(grade_cat, Treatment('A'))[T.D]     3.2612      6.625      0.492      0.623      -9.723      16.245
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                     0.0792      0.070      1.137      0.256      -0.057       0.216
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                      214.201   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11840.050
# Skew:                           5.260   Prob(JB):                         0.00
# Kurtosis:                      43.406   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Saved → LA_Regression_Results_LPM.csv
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %%
import pandas as pd
import numpy as np
import os

# ===== Load your regression results from earlier =====
df = pd.read_csv("LA_Regression_Results_LPM.csv")  # change filename if needed

# ===== APA formatting helpers =====
def format_p(p):
    if p < 0.001:
        return "< .001"
    elif p < 0.01:
        return f"{p:.3f}**"
    elif p < 0.05:
        return f"{p:.3f}*"
    else:
        return f"{p:.3f}"

def format_coef(coef, se):
    return f"{coef:.3f} ({se:.3f})"

# ===== Create output directory for APA tables =====
out_dir = "LA_apa_tables"
os.makedirs(out_dir, exist_ok=True)

apa_tables = {}

for model in df['model'].unique():
    sub = df[df['model'] == model].copy()

    # Create APA columns
    sub["Coef (SE)"] = [
        format_coef(c, s) for c, s in zip(sub["coef"], sub["std_err"])
    ]
    sub["p"] = sub["p_value"].apply(format_p)

    # Select clean APA-style columns
    apa = sub[["term", "Coef (SE)", "p"]]

    # Save CSV
    csv_path = os.path.join(out_dir, f"APA_{model}.csv")
    apa.to_csv(csv_path, index=False)

    # Save Markdown version (great for your paper)
    md_path = os.path.join(out_dir, f"APA_{model}.md")
    apa.to_markdown(md_path, index=False)

    print(f"Saved APA table for {model} → {csv_path}")

print("\nAll APA tables saved in folder:", os.path.abspath(out_dir))
# Out:
# Saved APA table for LA_LPM_AnySTEM_BinaryRedline → LA_apa_tables/APA_LA_LPM_AnySTEM_BinaryRedline.csv
# Saved APA table for LA_LPM_AnySTEM_GradeCat → LA_apa_tables/APA_LA_LPM_AnySTEM_GradeCat.csv
# Saved APA table for LA_LPM_TotalSTEM_BinaryRedline → LA_apa_tables/APA_LA_LPM_TotalSTEM_BinaryRedline.csv
# Saved APA table for LA_LPM_TotalSTEM_GradeCat → LA_apa_tables/APA_LA_LPM_TotalSTEM_GradeCat.csv
#
# All APA tables saved in folder: /Users/zoechan/Documents/GitHub/as.180.369/contrib/zoemchan/zoemchan-prelim-paper/paper/data/LA_apa_tables

# %%
# Baseline regression: Predict Total_Adv_STEM using HOLC grade only (as ordered categorical) via OLS.
# Then produce visualizations: mosaic/stacked bar, bar/point by grade, distributions, and scatter with jitter.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Use existing la_df in memory

# Simple baseline: encode grade as ordered categorical with integer codes for OLS
reg_df = la_df.copy()
reg_df = reg_df.dropna(subset=['grade'])
reg_df['grade_code'] = reg_df['grade'].cat.codes  # A=0, B=1, C=2, D=3

# OLS with intercept: Total_Adv_STEM ~ grade_code
model = smf.ols('Total_Adv_STEM ~ grade_code', data=reg_df).fit(cov_type='HC1')
print(model.summary())

# Stacked bar chart: fraction of schools with Has_Calc/CS/Physics by grade
flag_map = {'Yes': 1, 'No': 0}
flag_df = la_df.copy()
for col in ['Has_Calc','Has_CS','Has_Physics']:
    flag_df[col] = flag_df[col].map(flag_map)

share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])


plt.figure(figsize=(8,5))
plot_df = la_df.melt(id_vars='grade', value_vars=['Num_Calc_Classes','Num_CS_Classes','Num_Physics_Classes'], var_name='Subject', value_name='Classes')
sns.barplot(data=plot_df, x='grade', y='Classes', hue='Subject', estimator=np.mean, errorbar='se')
plt.title('Average Classes by Subject and HOLC Grade')
plt.ylabel('Average number of classes')
plt.xlabel('HOLC Grade')
plt.legend(title='Subject')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total_Adv_STEM   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8352
# Date:                Mon, 10 Nov 2025   Prob (F-statistic):              0.362
# Time:                        17:09:18   Log-Likelihood:                -619.29
# No. Observations:                 163   AIC:                             1243.
# Df Residuals:                     161   BIC:                             1249.
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.2865      2.403      1.784      0.074      -0.424       8.997
# grade_code     1.0755      1.177      0.914      0.361      -1.231       3.382
# ==============================================================================
# Omnibus:                      214.300   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11826.009
# Skew:                           5.265   Prob(JB):                         0.00
# Kurtosis:                      43.378   Cond. No.                         10.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# /var/folders/hz/d49rtbh904s9fy8xy2xyj8m40000gn/T/ipykernel_8246/1528632678.py:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])

# %% [markdown]
# ## Chicago Regressions

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# =========================
# 1. LOAD DATA
# =========================

chi_file = "All_Classes_HS_Chicago.csv"
chi_schools = pd.read_csv(chi_file, dtype=str)

nat_file = "National_Schools_with_AdvancedSTEM_Expanded.csv"
nat = pd.read_csv(nat_file, dtype=str)

chi_schools["NCESSCH"] = chi_schools["NCESSCH"].astype(str)
nat["NCESSCH"] = nat["NCESSCH"].astype(str)

# =========================
# 2. MERGE INTO NATIONAL DATA
# =========================

chi_ids = chi_schools[["NCESSCH"]].drop_duplicates()
df = chi_ids.merge(nat, on="NCESSCH", how="left")

print(f"Chicago matched schools: {len(df)}")

# =========================
# 3. CLEAN HOLC GRADE
# =========================

df["grade"] = df["grade"].astype(str).str.strip().str.upper()
valid_grades = ["A", "B", "C", "D"]
df = df[df["grade"].isin(valid_grades)].copy()

df["grade_cat"] = pd.Categorical(df["grade"], categories=["A", "B", "C", "D"], ordered=True)
df["Redline_CD"] = df["grade"].isin(["C", "D"]).astype(int)

# =========================
# 4. STEM VARIABLES
# =========================

for col in ["Num_Calc_Classes", "Num_CS_Classes", "Num_Physics_Classes"]:
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

df["Has_Calc_bin"] = df["Has_Calc"].map({"Yes":1, "No":0})
df["Has_CS_bin"] = df["Has_CS"].map({"Yes":1, "No":0})
df["Has_Physics_bin"] = df["Has_Physics"].map({"Yes":1, "No":0})

df["Any_STEM"] = (
    df["Has_Calc_bin"] | df["Has_CS_bin"] | df["Has_Physics_bin"]
).astype(int)

df["Total_STEM_Classes"] = (
      df["Num_Calc_Classes"]
    + df["Num_CS_Classes"]
    + df["Num_Physics_Classes"]
)

# =========================
# 5. ROBUSTLY HANDLE CONTROL VARIABLES
# =========================

control_vars = ["MAGNET_FLAG", "CHARTER_FLAG", "TITLE1_FLAG", "PCT_CERTIFIED_FTE"]

# Check which controls are missing
missing_controls = [c for c in control_vars if c not in df.columns]
if missing_controls:
    print("The following control variables were missing and will be created as 0:", missing_controls)

# Create missing controls with safe defaults
for col in missing_controls:
    df[col] = 0

# Convert flags to 0/1 safely
def make_flag(col):
    return col.astype(str).str.upper().map(
        {"YES":1, "NO":0, "1":1, "0":0}
    ).fillna(0).astype(int)

df["MAGNET_FLAG"] = make_flag(df["MAGNET_FLAG"])
df["CHARTER_FLAG"] = make_flag(df["CHARTER_FLAG"])
df["TITLE1_FLAG"] = make_flag(df["TITLE1_FLAG"])

# Handle certified teacher %
df["PCT_CERTIFIED_FTE"] = pd.to_numeric(df["PCT_CERTIFIED_FTE"], errors="coerce").fillna(0)

reg_df = df.dropna(subset=["Any_STEM", "Total_STEM_Classes"])
print("Final Chicago sample:", len(reg_df))

# =========================
# 6. Regression Helper (HC3 robust)
# =========================

def run_lpm(formula, name):
    model = smf.ols(formula, data=reg_df)
    res = model.fit(cov_type="HC3")
    print("\n=====", name, "=====")
    print(res.summary())

    return pd.DataFrame({
        "term":res.params.index,
        "coef":res.params.values,
        "std_err":res.bse.values,
        "t":res.tvalues.values,
        "p":res.pvalues.values,
        "model":name
    })

# =========================
# 7. Run Chicago Regressions
# =========================

results = []

formulas = {
    "CHI_LPM_AnySTEM_BinaryRedline": """
        Any_STEM ~ Redline_CD + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "CHI_LPM_AnySTEM_GradeCat": """
        Any_STEM ~ C(grade_cat, Treatment('A')) + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "CHI_LPM_TotalSTEM_BinaryRedline": """
        Total_STEM_Classes ~ Redline_CD + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "CHI_LPM_TotalSTEM_GradeCat": """
        Total_STEM_Classes ~ C(grade_cat, Treatment('A')) + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """
}

for name, formula in formulas.items():
    results.append(run_lpm(formula, name))

final = pd.concat(results, ignore_index=True)
final.to_csv("Chicago_Regression_Results_LPM.csv", index=False)

print("\nSaved Chicago_Regression_Results_LPM.csv")
# Out:
# Chicago matched schools: 113
# The following control variables were missing and will be created as 0: ['MAGNET_FLAG', 'CHARTER_FLAG']
# Final Chicago sample: 111
#
# ===== CHI_LPM_AnySTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                     9.741
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           0.000129
# Time:                        18:01:01   Log-Likelihood:                -43.374
# No. Observations:                 111   AIC:                             92.75
# Df Residuals:                     108   BIC:                             100.9
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.1424      0.171      6.695      0.000       0.808       1.477
# Redline_CD           -0.1738      0.042     -4.151      0.000      -0.256      -0.092
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE    -0.0015      0.002     -0.835      0.404      -0.005       0.002
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       43.586   Durbin-Watson:                   1.799
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.257
# Skew:                          -1.878   Prob(JB):                     1.67e-17
# Kurtosis:                       4.612   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== CHI_LPM_AnySTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                 2.437e+04
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):          2.40e-157
# Time:                        18:01:01   Log-Likelihood:                -43.073
# No. Observations:                 111   AIC:                             94.15
# Df Residuals:                     107   BIC:                             105.0
# Df Model:                           3
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.7507      0.117      6.440      0.000       0.522       0.979
# C(grade_cat, Treatment('A'))[T.B]     0.3647      0.055      6.678      0.000       0.258       0.472
# C(grade_cat, Treatment('A'))[T.C]     0.1656      0.051      3.257      0.001       0.066       0.265
# C(grade_cat, Treatment('A'))[T.D]     0.2204      0.051      4.299      0.000       0.120       0.321
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                    -0.0012      0.002     -0.693      0.488      -0.005       0.002
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       43.278   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.357
# Skew:                          -1.866   Prob(JB):                     2.63e-17
# Kurtosis:                       4.608   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== CHI_LPM_TotalSTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     7.990
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           0.000581
# Time:                        18:01:01   Log-Likelihood:                -430.29
# No. Observations:                 111   AIC:                             866.6
# Df Residuals:                     108   BIC:                             874.7
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.9394      8.020      0.117      0.907     -14.780      16.659
# Redline_CD           -6.0505      7.003     -0.864      0.388     -19.776       7.675
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE     0.1742      0.047      3.747      0.000       0.083       0.265
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       52.566   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.052
# Skew:                           1.831   Prob(JB):                     1.05e-30
# Kurtosis:                       7.054   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== CHI_LPM_TotalSTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     23.94
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           3.69e-14
# Time:                        18:01:01   Log-Likelihood:                -430.21
# No. Observations:                 111   AIC:                             868.4
# Df Residuals:                     107   BIC:                             879.2
# Df Model:                           3
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.6524      3.489     -0.760      0.447      -9.490       4.185
# C(grade_cat, Treatment('A'))[T.B]     3.1262      5.438      0.575      0.565      -7.532      13.784
# C(grade_cat, Treatment('A'))[T.C]    -3.3624      2.463     -1.365      0.172      -8.190       1.465
# C(grade_cat, Treatment('A'))[T.D]    -2.4162      2.043     -1.183      0.237      -6.421       1.589
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                     0.1791      0.052      3.450      0.001       0.077       0.281
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       51.493   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.910
# Skew:                           1.809   Prob(JB):                     3.74e-29
# Kurtosis:                       6.900   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Saved Chicago_Regression_Results_LPM.csv
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %%
# Baseline regression: Predict Total_Adv_STEM using HOLC grade only (as ordered categorical) via OLS.
# Then produce visualizations: mosaic/stacked bar, bar/point by grade, distributions, and scatter with jitter.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Use existing la_df in memory

# Simple baseline: encode grade as ordered categorical with integer codes for OLS
reg_df = la_df.copy()
reg_df = reg_df.dropna(subset=['grade'])
reg_df['grade_code'] = reg_df['grade'].cat.codes  # A=0, B=1, C=2, D=3

# OLS with intercept: Total_Adv_STEM ~ grade_code
model = smf.ols('Total_Adv_STEM ~ grade_code', data=reg_df).fit(cov_type='HC1')
print(model.summary())

# Stacked bar chart: fraction of schools with Has_Calc/CS/Physics by grade
flag_map = {'Yes': 1, 'No': 0}
flag_df = la_df.copy()
for col in ['Has_Calc','Has_CS','Has_Physics']:
    flag_df[col] = flag_df[col].map(flag_map)

share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])


plt.figure(figsize=(8,5))
plot_df = la_df.melt(id_vars='grade', value_vars=['Num_Calc_Classes','Num_CS_Classes','Num_Physics_Classes'], var_name='Subject', value_name='Classes')
sns.barplot(data=plot_df, x='grade', y='Classes', hue='Subject', estimator=np.mean, errorbar='se')
plt.title('Average Classes by Subject and HOLC Grade')
plt.ylabel('Average number of classes')
plt.xlabel('HOLC Grade')
plt.legend(title='Subject')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total_Adv_STEM   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.6115
# Date:                Mon, 10 Nov 2025   Prob (F-statistic):              0.436
# Time:                        17:12:36   Log-Likelihood:                -434.53
# No. Observations:                 111   AIC:                             873.1
# Df Residuals:                     109   BIC:                             878.5
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.3026      5.114      2.797      0.005       4.280      24.325
# grade_code    -1.6295      2.084     -0.782      0.434      -5.713       2.455
# ==============================================================================
# Omnibus:                       58.763   Durbin-Watson:                   1.612
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.687
# Skew:                           2.029   Prob(JB):                     1.42e-37
# Kurtosis:                       7.496   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# /var/folders/hz/d49rtbh904s9fy8xy2xyj8m40000gn/T/ipykernel_8246/300213310.py:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])

# %% [markdown]
# ## Detroit Regressions

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# =========================
# 1. LOAD DATA
# =========================

det_file = "Detroit_Schools_with_AdvancedSTEM.csv"
det_schools = pd.read_csv(det_file, dtype=str)

nat = pd.read_csv("National_Schools_with_AdvancedSTEM_Expanded.csv", dtype=str)

det_schools["NCESSCH"] = det_schools["NCESSCH"].astype(str)
nat["NCESSCH"] = nat["NCESSCH"].astype(str)

# =========================
# 2. MERGE INTO NATIONAL DATA
# =========================

det_ids = det_schools[["NCESSCH"]].drop_duplicates()
df = det_ids.merge(nat, on="NCESSCH", how="left")

print("Detroit matched schools:", len(df))

# =========================
# 3. CLEAN HOLC GRADE
# =========================

df["grade"] = df["grade"].astype(str).str.strip().str.upper()
valid_grades = ["A", "B", "C", "D"]
df = df[df["grade"].isin(valid_grades)].copy()

df["grade_cat"] = pd.Categorical(df["grade"], categories=["A", "B", "C", "D"], ordered=True)
df["Redline_CD"] = df["grade"].isin(["C", "D"]).astype(int)

# =========================
# 4. STEM VARIABLES
# =========================

for col in ["Num_Calc_Classes", "Num_CS_Classes", "Num_Physics_Classes"]:
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

df["Has_Calc_bin"] = df["Has_Calc"].map({"Yes":1,"No":0})
df["Has_CS_bin"] = df["Has_CS"].map({"Yes":1,"No":0})
df["Has_Physics_bin"] = df["Has_Physics"].map({"Yes":1,"No":0})

df["Any_STEM"] = (
    df["Has_Calc_bin"] | df["Has_CS_bin"] | df["Has_Physics_bin"]
).astype(int)

df["Total_STEM_Classes"] = (
    df["Num_Calc_Classes"] +
    df["Num_CS_Classes"] +
    df["Num_Physics_Classes"]
)

# =========================
# 5. ROBUSTLY HANDLE CONTROL VARIABLES
# =========================

control_vars = ["MAGNET_FLAG", "CHARTER_FLAG", "TITLE1_FLAG", "PCT_CERTIFIED_FTE"]

# Identify missing ones
missing_controls = [c for c in control_vars if c not in df.columns]
if missing_controls:
    print("Missing controls (created as 0):", missing_controls)

# Create missing controls
for col in missing_controls:
    df[col] = 0

# Clean flag-like columns
def make_flag(col):
    return col.astype(str).str.upper().map(
        {"YES":1, "NO":0, "1":1, "0":0}
    ).fillna(0).astype(int)

df["MAGNET_FLAG"] = make_flag(df["MAGNET_FLAG"])
df["CHARTER_FLAG"] = make_flag(df["CHARTER_FLAG"])
df["TITLE1_FLAG"] = make_flag(df["TITLE1_FLAG"])

df["PCT_CERTIFIED_FTE"] = pd.to_numeric(df["PCT_CERTIFIED_FTE"], errors="coerce").fillna(0)

reg_df = df.dropna(subset=["Any_STEM", "Total_STEM_Classes"])
print("Final Detroit sample:", len(reg_df))

# =========================
# 6. Regression Helper (HC3 robust)
# =========================

def run_lpm(formula, name):
    model = smf.ols(formula, data=reg_df)
    res = model.fit(cov_type="HC3")
    print("\n=====", name, "=====")
    print(res.summary())
    return pd.DataFrame({
        "term":res.params.index,
        "coef":res.params.values,
        "std_err":res.bse.values,
        "t":res.tvalues.values,
        "p":res.pvalues.values,
        "model":name
    })

# =========================
# 7. Run Detroit Regressions
# =========================

results = []
formulas = {
    "DET_LPM_AnySTEM_BinaryRedline": """
        Any_STEM ~ Redline_CD + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "DET_LPM_AnySTEM_GradeCat": """
        Any_STEM ~ C(grade_cat, Treatment('A')) + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "DET_LPM_TotalSTEM_BinaryRedline": """
        Total_STEM_Classes ~ Redline_CD + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "DET_LPM_TotalSTEM_GradeCat": """
        Total_STEM_Classes ~ C(grade_cat, Treatment('A')) + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """
}

for name, formula in formulas.items():
    results.append(run_lpm(formula, name))

final = pd.concat(results, ignore_index=True)
final.to_csv("Detroit_Regression_Results_LPM.csv", index=False)

print("\nSaved Detroit_Regression_Results_LPM.csv")
# Out:
# Detroit matched schools: 85
# Missing controls (created as 0): ['MAGNET_FLAG', 'CHARTER_FLAG']
# Final Detroit sample: 85
#
# ===== DET_LPM_AnySTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     16.26
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           1.13e-06
# Time:                        18:01:19   Log-Likelihood:                -51.076
# No. Observations:                  85   AIC:                             108.2
# Df Residuals:                      82   BIC:                             115.5
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.8281      0.253      3.275      0.001       0.332       1.324
# Redline_CD           -0.2829      0.060     -4.711      0.000      -0.401      -0.165
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE     0.0018      0.003      0.680      0.497      -0.003       0.007
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       26.496   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.428
# Skew:                          -0.890   Prob(JB):                     0.000446
# Kurtosis:                       1.911   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== DET_LPM_AnySTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                     7.955
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):           1.89e-05
# Time:                        18:01:19   Log-Likelihood:                -50.861
# No. Observations:                  85   AIC:                             111.7
# Df Residuals:                      80   BIC:                             123.9
# Df Model:                           4
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.8492      0.256      3.319      0.001       0.348       1.351
# C(grade_cat, Treatment('A'))[T.B]    -0.0050      0.054     -0.092      0.926      -0.111       0.101
# C(grade_cat, Treatment('A'))[T.C]    -0.2520      0.075     -3.346      0.001      -0.400      -0.104
# C(grade_cat, Treatment('A'))[T.D]    -0.3178      0.087     -3.669      0.000      -0.488      -0.148
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                     0.0016      0.003      0.590      0.555      -0.004       0.007
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       25.929   Durbin-Watson:                   1.529
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.107
# Skew:                          -0.879   Prob(JB):                     0.000524
# Kurtosis:                       1.916   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== DET_LPM_TotalSTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     5.072
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):            0.00838
# Time:                        18:01:19   Log-Likelihood:                -348.07
# No. Observations:                  85   AIC:                             702.1
# Df Residuals:                      82   BIC:                             709.5
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            25.4798     11.322      2.250      0.024       3.289      47.671
# Redline_CD          -24.4881     11.180     -2.190      0.028     -46.400      -2.576
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE     0.0738      0.035      2.127      0.033       0.006       0.142
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       91.543   Durbin-Watson:                   1.340
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1009.831
# Skew:                           3.434   Prob(JB):                    5.22e-220
# Kurtosis:                      18.426   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== DET_LPM_TotalSTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.197
# Method:                 Least Squares   F-statistic:                     3.099
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):             0.0200
# Time:                        18:01:19   Log-Likelihood:                -344.96
# No. Observations:                  85   AIC:                             699.9
# Df Residuals:                      80   BIC:                             712.1
# Df Model:                           4
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            31.9942     12.173      2.628      0.009       8.135      55.854
# C(grade_cat, Treatment('A'))[T.B]   -30.9919     26.540     -1.168      0.243     -83.010      21.026
# C(grade_cat, Treatment('A'))[T.C]   -27.2652     12.219     -2.231      0.026     -51.214      -3.316
# C(grade_cat, Treatment('A'))[T.D]   -32.1833     11.994     -2.683      0.007     -55.692      -8.675
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                     0.0600      0.032      1.865      0.062      -0.003       0.123
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       94.158   Durbin-Watson:                   1.440
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1098.142
# Skew:                           3.555   Prob(JB):                    3.48e-239
# Kurtosis:                      19.110   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Saved Detroit_Regression_Results_LPM.csv
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Use existing la_df in memory

# Simple baseline: encode grade as ordered categorical with integer codes for OLS
reg_df = la_df.copy()
reg_df = reg_df.dropna(subset=['grade'])
reg_df['grade_code'] = reg_df['grade'].cat.codes  # A=0, B=1, C=2, D=3

# OLS with intercept: Total_Adv_STEM ~ grade_code
model = smf.ols('Total_Adv_STEM ~ grade_code', data=reg_df).fit(cov_type='HC1')
print(model.summary())

# Stacked bar chart: fraction of schools with Has_Calc/CS/Physics by grade
flag_map = {'Yes': 1, 'No': 0}
flag_df = la_df.copy()
for col in ['Has_Calc','Has_CS','Has_Physics']:
    flag_df[col] = flag_df[col].map(flag_map)

share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])


plt.figure(figsize=(8,5))
plot_df = la_df.melt(id_vars='grade', value_vars=['Num_Calc_Classes','Num_CS_Classes','Num_Physics_Classes'], var_name='Subject', value_name='Classes')
sns.barplot(data=plot_df, x='grade', y='Classes', hue='Subject', estimator=np.mean, errorbar='se')
plt.title('Average Classes by Subject and HOLC Grade')
plt.ylabel('Average number of classes')
plt.xlabel('HOLC Grade')
plt.legend(title='Subject')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total_Adv_STEM   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     12.01
# Date:                Mon, 10 Nov 2025   Prob (F-statistic):           0.000840
# Time:                        17:18:28   Log-Likelihood:                -347.25
# No. Observations:                  85   AIC:                             698.5
# Df Residuals:                      83   BIC:                             703.4
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.3675      6.970      4.357      0.000      16.707      44.028
# grade_code    -9.0412      2.609     -3.466      0.001     -14.154      -3.928
# ==============================================================================
# Omnibus:                       88.852   Durbin-Watson:                   1.441
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              871.747
# Skew:                           3.353   Prob(JB):                    5.04e-190
# Kurtosis:                      17.184   Cond. No.                         9.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# /var/folders/hz/d49rtbh904s9fy8xy2xyj8m40000gn/T/ipykernel_8246/3365745511.py:25: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])

# %% [markdown]
# ## Philly Regressions

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# =========================
# 1. LOAD DATA
# =========================

phl_file = "Philly_Schools_with_AdvancedSTEM.csv"
phl_schools = pd.read_csv(phl_file, dtype=str)

nat = pd.read_csv("National_Schools_with_AdvancedSTEM_Expanded.csv", dtype=str)

phl_schools["NCESSCH"] = phl_schools["NCESSCH"].astype(str)
nat["NCESSCH"] = nat["NCESSCH"].astype(str)

# =========================
# 2. MERGE INTO NATIONAL DATA
# =========================

phl_ids = phl_schools[["NCESSCH"]].drop_duplicates()
df = phl_ids.merge(nat, on="NCESSCH", how="left")

print("Philadelphia matched:", len(df))

# =========================
# 3. CLEAN HOLC GRADE
# =========================

df["grade"] = df["grade"].astype(str).str.strip().str.upper()
df = df[df["grade"].isin(["A","B","C","D"])].copy()

df["grade_cat"] = pd.Categorical(
    df["grade"],
    categories=["A","B","C","D"],
    ordered=True
)
df["Redline_CD"] = df["grade"].isin(["C","D"]).astype(int)

# =========================
# 4. STEM VARIABLES
# =========================

for col in ["Num_Calc_Classes","Num_CS_Classes","Num_Physics_Classes"]:
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

df["Has_Calc_bin"]    = df["Has_Calc"].map({"Yes":1,"No":0})
df["Has_CS_bin"]      = df["Has_CS"].map({"Yes":1,"No":0})
df["Has_Physics_bin"] = df["Has_Physics"].map({"Yes":1,"No":0})

df["Any_STEM"] = (
    df["Has_Calc_bin"] | df["Has_CS_bin"] | df["Has_Physics_bin"]
).astype(int)

df["Total_STEM_Classes"] = (
    df["Num_Calc_Classes"] +
    df["Num_CS_Classes"] +
    df["Num_Physics_Classes"]
)

# =========================
# 5. ROBUSTLY HANDLE CONTROLS
# =========================

control_vars = ["MAGNET_FLAG", "CHARTER_FLAG", "TITLE1_FLAG", "PCT_CERTIFIED_FTE"]

missing_controls = [c for c in control_vars if c not in df.columns]
if missing_controls:
    print("Missing controls (created as 0):", missing_controls)

for col in missing_controls:
    df[col] = 0

def make_flag(col):
    return col.astype(str).str.upper().map(
        {"YES":1,"NO":0,"1":1,"0":0}
    ).fillna(0).astype(int)

df["MAGNET_FLAG"]  = make_flag(df["MAGNET_FLAG"])
df["CHARTER_FLAG"] = make_flag(df["CHARTER_FLAG"])
df["TITLE1_FLAG"]  = make_flag(df["TITLE1_FLAG"])

df["PCT_CERTIFIED_FTE"] = pd.to_numeric(df["PCT_CERTIFIED_FTE"], errors="coerce").fillna(0)

reg_df = df.dropna(subset=["Any_STEM","Total_STEM_Classes"])
print("Final Philadelphia sample:", len(reg_df))

# =========================
# 6. Robust Regression Helper
# =========================

def run_lpm(formula, name):
    res = smf.ols(formula, data=reg_df).fit(cov_type="HC3")
    print("\n=====", name, "=====")
    print(res.summary())
    return pd.DataFrame({
        "term":res.params.index,
        "coef":res.params.values,
        "std_err":res.bse.values,
        "t":res.tvalues.values,
        "p":res.pvalues.values,
        "model":name
    })

# =========================
# 7. Run Philadelphia Regressions
# =========================

results = []

formulas = {
    "PHL_LPM_AnySTEM_BinaryRedline": """
        Any_STEM ~ Redline_CD + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "PHL_LPM_AnySTEM_GradeCat": """
        Any_STEM ~ C(grade_cat, Treatment('A')) + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "PHL_LPM_TotalSTEM_BinaryRedline": """
        Total_STEM_Classes ~ Redline_CD + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """,
    "PHL_LPM_TotalSTEM_GradeCat": """
        Total_STEM_Classes ~ C(grade_cat, Treatment('A')) + MAGNET_FLAG + CHARTER_FLAG + PCT_CERTIFIED_FTE + TITLE1_FLAG
    """
}

for name, formula in formulas.items():
    results.append(run_lpm(formula, name))

final = pd.concat(results, ignore_index=True)
final.to_csv("Philly_Regression_Results_LPM.csv", index=False)

print("\nSaved Philly_Regression_Results_LPM.csv")
# Out:
# Philadelphia matched: 65
# Missing controls (created as 0): ['MAGNET_FLAG', 'CHARTER_FLAG']
# Final Philadelphia sample: 65
#
# ===== PHL_LPM_AnySTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.3529
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.704
# Time:                        18:02:02   Log-Likelihood:                -30.073
# No. Observations:                  65   AIC:                             66.15
# Df Residuals:                      62   BIC:                             72.67
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.3800      0.645      0.589      0.556      -0.884       1.644
# Redline_CD            0.0839      0.130      0.646      0.518      -0.171       0.339
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE     0.0042      0.007      0.611      0.541      -0.009       0.018
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       20.859   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.865
# Skew:                          -1.574   Prob(JB):                     8.89e-07
# Kurtosis:                       3.620   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== PHL_LPM_AnySTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Any_STEM   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                    0.7073
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.590
# Time:                        18:02:02   Log-Likelihood:                -29.792
# No. Observations:                  65   AIC:                             69.58
# Df Residuals:                      60   BIC:                             80.46
# Df Model:                           4
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.6121      0.695      0.880      0.379      -0.751       1.975
# C(grade_cat, Treatment('A'))[T.B]    -0.2182      0.177     -1.232      0.218      -0.565       0.129
# C(grade_cat, Treatment('A'))[T.C]    -0.0824      0.171     -0.482      0.630      -0.417       0.252
# C(grade_cat, Treatment('A'))[T.D]    -0.1425      0.143     -0.994      0.320      -0.424       0.139
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                     0.0039      0.007      0.566      0.572      -0.010       0.017
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       20.520   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.196
# Skew:                          -1.555   Prob(JB):                     1.24e-06
# Kurtosis:                       3.610   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== PHL_LPM_TotalSTEM_BinaryRedline =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.3670
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.694
# Time:                        18:02:02   Log-Likelihood:                -225.51
# No. Observations:                  65   AIC:                             457.0
# Df Residuals:                      62   BIC:                             463.5
# Df Model:                           2
# Covariance Type:                  HC3
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            14.1841     10.891      1.302      0.193      -7.161      35.530
# Redline_CD           -2.2901      3.089     -0.741      0.458      -8.344       3.764
# MAGNET_FLAG                0          0        nan        nan           0           0
# CHARTER_FLAG               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE    -0.0606      0.113     -0.536      0.592      -0.283       0.161
# TITLE1_FLAG                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       37.819   Durbin-Watson:                   2.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.547
# Skew:                           1.807   Prob(JB):                     5.40e-23
# Kurtosis:                       7.980   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ===== PHL_LPM_TotalSTEM_GradeCat =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total_STEM_Classes   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.310
# Date:                Sun, 16 Nov 2025   Prob (F-statistic):              0.277
# Time:                        18:02:02   Log-Likelihood:                -223.67
# No. Observations:                  65   AIC:                             457.3
# Df Residuals:                      60   BIC:                             468.2
# Df Model:                           4
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            29.5779     13.764      2.149      0.032       2.601      56.555
# C(grade_cat, Treatment('A'))[T.B]   -14.8718      7.961     -1.868      0.062     -30.475       0.731
# C(grade_cat, Treatment('A'))[T.C]   -16.9570      7.590     -2.234      0.025     -31.833      -2.081
# C(grade_cat, Treatment('A'))[T.D]   -16.0355      7.578     -2.116      0.034     -30.889      -1.182
# MAGNET_FLAG                                0          0        nan        nan           0           0
# CHARTER_FLAG                               0          0        nan        nan           0           0
# PCT_CERTIFIED_FTE                    -0.0758      0.116     -0.651      0.515      -0.304       0.152
# TITLE1_FLAG                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       44.716   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              159.904
# Skew:                           2.033   Prob(JB):                     1.89e-35
# Kurtosis:                       9.519   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Saved Philly_Regression_Results_LPM.csv
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/zoechan/opt/anaconda3/envs/geo/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Use existing la_df in memory

# Simple baseline: encode grade as ordered categorical with integer codes for OLS
reg_df = la_df.copy()
reg_df = reg_df.dropna(subset=['grade'])
reg_df['grade_code'] = reg_df['grade'].cat.codes  # A=0, B=1, C=2, D=3

# OLS with intercept: Total_Adv_STEM ~ grade_code
model = smf.ols('Total_Adv_STEM ~ grade_code', data=reg_df).fit(cov_type='HC1')
print(model.summary())

# Stacked bar chart: fraction of schools with Has_Calc/CS/Physics by grade
flag_map = {'Yes': 1, 'No': 0}
flag_df = la_df.copy()
for col in ['Has_Calc','Has_CS','Has_Physics']:
    flag_df[col] = flag_df[col].map(flag_map)

share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])


plt.figure(figsize=(8,5))
plot_df = la_df.melt(id_vars='grade', value_vars=['Num_Calc_Classes','Num_CS_Classes','Num_Physics_Classes'], var_name='Subject', value_name='Classes')
sns.barplot(data=plot_df, x='grade', y='Classes', hue='Subject', estimator=np.mean, errorbar='se')
plt.title('Average Classes by Subject and HOLC Grade')
plt.ylabel('Average number of classes')
plt.xlabel('HOLC Grade')
plt.legend(title='Subject')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Total_Adv_STEM   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.4924
# Date:                Mon, 10 Nov 2025   Prob (F-statistic):              0.485
# Time:                        17:19:29   Log-Likelihood:                -225.79
# No. Observations:                  65   AIC:                             455.6
# Df Residuals:                      63   BIC:                             459.9
# Df Model:                           1
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.2261      3.620      2.548      0.011       2.130      16.322
# grade_code    -0.9771      1.392     -0.702      0.483      -3.706       1.752
# ==============================================================================
# Omnibus:                       37.777   Durbin-Watson:                   2.226
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.689
# Skew:                           1.810   Prob(JB):                     8.29e-23
# Kurtosis:                       7.944   Cond. No.                         7.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# /var/folders/hz/d49rtbh904s9fy8xy2xyj8m40000gn/T/ipykernel_8246/3365745511.py:25: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   share_by_grade = flag_df.groupby('grade')[['Has_Calc','Has_CS','Has_Physics']].mean().reindex(['A','B','C','D'])

# %% [markdown]
# # Summary Data

# %%
import pandas as pd
import os
import numpy as np

# ===============================
# File mapping for each city
# ===============================
files = {
    "Chicago": "Chicago_Regression_Results_LPM.csv",
    "Detroit": "Detroit_Regression_Results_LPM.csv",
    "LA": "LA_Regression_Results_LPM.csv",
    "Philly": "Philly_Regression_Results_LPM.csv"
}

# ===============================
# Regression model prefixes
# ===============================
prefix_map = {
    "Chicago": "CHI",
    "Detroit": "DET",
    "LA": "LA",
    "Philly": "PHL"
}

# ===============================
# Output folder
# ===============================
out_dir = "Unified_Summaries"
os.makedirs(out_dir, exist_ok=True)

# ===============================
# Helpers: extract coef/se/p + format with stars
# ===============================
def sig_stars(p):
    """Return significance stars for a p-value."""
    if p is None or (isinstance(p, float) and np.isnan(p)):
        return ""
    if p < 0.001:
        return "***"
    if p < 0.01:
        return "**"
    if p < 0.05:
        return "*"
    if p < 0.10:
        return "†"
    return ""

def get_stats(df, model_name, term, p_col="p"):
    """
    Return (coef, se, p) for a given model + term.
    Returns (None, None, None) if not found.
    """
    subset = df[(df["model"] == model_name) & (df["term"] == term)]
    if len(subset) == 0:
        return None, None, None

    coef = subset["coef"].iloc[0]
    se = subset["std_err"].iloc[0] if "std_err" in subset.columns else None
    p = subset[p_col].iloc[0] if p_col in subset.columns else None

    # Coerce to floats when possible
    try: coef = float(coef)
    except: coef = None
    try: se = float(se) if se is not None else None
    except: se = None
    try: p = float(p) if p is not None else None
    except: p = None

    return coef, se, p

def fmt_coef_se(coef, se, p, digits=3):
    """
    Format like: -0.105† (0.054)
    If se missing: -0.105†
    If coef missing: —
    """
    if coef is None or (isinstance(coef, float) and np.isnan(coef)):
        return "—"

    stars = sig_stars(p)
    coef_str = f"{coef:.{digits}f}{stars}"

    if se is None or (isinstance(se, float) and np.isnan(se)):
        return coef_str

    se_str = f"{se:.{digits}f}"
    return f"{coef_str} ({se_str})"


# ===============================
# Load regression CSVs
# ===============================
city_dfs = {city: pd.read_csv(path) for city, path in files.items()}

# If your p-value column is not named "p", change it here:
P_COL = "p"

# ===============================
# === Table A: Binary Redline Effects ===
# ===============================
tableA = []

for city, df in city_dfs.items():
    prefix = prefix_map[city]

    # AnySTEM (binary redline)
    coef, se, p = get_stats(df, f"{prefix}_LPM_AnySTEM_BinaryRedline", "Redline_CD", p_col=P_COL)
    anystem = fmt_coef_se(coef, se, p, digits=3)

    # TotalSTEM (binary redline)
    coef, se, p = get_stats(df, f"{prefix}_LPM_TotalSTEM_BinaryRedline", "Redline_CD", p_col=P_COL)
    totalstem = fmt_coef_se(coef, se, p, digits=3)

    tableA.append({
        "City": city,
        "Binary Redline Effect (Any STEM)": anystem,
        "Binary Redline Effect (Total STEM)": totalstem
    })

tableA = pd.DataFrame(tableA)
tableA.to_csv(os.path.join(out_dir, "TableA_BinaryRedline.csv"), index=False)
tableA.to_markdown(os.path.join(out_dir, "TableA_BinaryRedline.md"), index=False)

# ===============================
# === Table B: Grade Categories (B/C/D compared to A) ===
# ===============================
grade_terms = [
    "C(grade_cat, Treatment('A'))[T.B]",
    "C(grade_cat, Treatment('A'))[T.C]",
    "C(grade_cat, Treatment('A'))[T.D]"
]

tableB = []

for city, df in city_dfs.items():
    prefix = prefix_map[city]
    row = {"City": city}

    # AnySTEM
    model_any = f"{prefix}_LPM_AnySTEM_GradeCat"
    for lab, term in zip(["B", "C", "D"], grade_terms):
        coef, se, p = get_stats(df, model_any, term, p_col=P_COL)
        row[f"AnySTEM_{lab}"] = fmt_coef_se(coef, se, p, digits=3)

    # TotalSTEM
    model_tot = f"{prefix}_LPM_TotalSTEM_GradeCat"
    for lab, term in zip(["B", "C", "D"], grade_terms):
        coef, se, p = get_stats(df, model_tot, term, p_col=P_COL)
        row[f"TotalSTEM_{lab}"] = fmt_coef_se(coef, se, p, digits=3)

    tableB.append(row)

tableB = pd.DataFrame(tableB)
tableB.to_csv(os.path.join(out_dir, "TableB_GradeCategories.csv"), index=False)
tableB.to_markdown(os.path.join(out_dir, "TableB_GradeCategories.md"), index=False)

# ===============================
# === Table C: Control Variables (with SE + stars) ===
# ===============================
controls = ["MAGNET_FLAG", "CHARTER_FLAG", "PCT_CERTIFIED_FTE", "TITLE1_FLAG"]

tableC = []

for city, df in city_dfs.items():
    prefix = prefix_map[city]
    model_bin = f"{prefix}_LPM_AnySTEM_BinaryRedline"

    row = {"City": city}
    for ctrl in controls:
        coef, se, p = get_stats(df, model_bin, ctrl, p_col=P_COL)
        row[ctrl] = fmt_coef_se(coef, se, p, digits=3)

    tableC.append(row)

tableC = pd.DataFrame(tableC)
tableC.to_csv(os.path.join(out_dir, "TableC_Controls.csv"), index=False)
tableC.to_markdown(os.path.join(out_dir, "TableC_Controls.md"), index=False)

# ===============================
# Add a small "key" file for notes (optional but handy)
# ===============================
notes_path = os.path.join(out_dir, "Significance_Key.md")
with open(notes_path, "w") as f:
    f.write("**Significance key:** † p < .10, * p < .05, ** p < .01, *** p < .001\n")

print("\n✅ Unified summary tables created successfully (with SEs + significance stars)!")
print(f"📁 Saved in folder: {os.path.abspath(out_dir)}")
# Out:
# ✅ Unified summary tables created successfully (with SEs + significance stars)!
# 📁 Saved in folder: /Users/zoechan/Documents/GitHub/as.180.369/contrib/zoemchan/zoemchan_final_paper/zoemchan-prelim-paper/paper/data/Unified_Summaries

# %% [markdown]
# ## Merged % Bar Charts

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ---------- File mapping ----------
city_files = {
    "Chicago": "All_Classes_HS_Chicago.csv",
    "Los Angeles": "LA_Schools_With_AdvancedSTEM.csv",
    "Philadelphia": "Philly_Schools_With_AdvancedSTEM.csv",
    "Detroit": "Detroit_Schools_With_AdvancedSTEM.csv"
}

# ---------- Helper: Process a city file ----------
def process_city(filepath):
    df = pd.read_csv(filepath)

    # Create Course_Profile (0–3)
    df["Course_Profile"] = (
        df["Has_Calc"].map({"Yes": 1, "No": 0}) +
        df["Has_CS"].map({"Yes": 1, "No": 0}) +
        df["Has_Physics"].map({"Yes": 1, "No": 0})
    )

    # Count and percentages
    profile_counts = df.groupby(["grade", "Course_Profile"]).size().unstack(fill_value=0)
    profile_percents = profile_counts.div(profile_counts.sum(axis=1), axis=0) * 100

    return df, profile_counts, profile_percents


# ---------- Create 2×2 figure ----------
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.flatten()

combined_tables = []  # to store combined summary tables

for ax, (city, filepath) in zip(axes, city_files.items()):
    df, counts, percents = process_city(filepath)

    # Plot stacked bars
    percents.plot(
        kind="bar",
        stacked=True,
        colormap="viridis",
        ax=ax
    )

    # Add school count labels
    totals = counts.sum(axis=1)
    for i, total in enumerate(totals):
        ax.text(
            i, 105,
            f"{int(total)} schools",
            ha="center",
            va="bottom",
            fontsize=9,
            fontweight="bold"
        )

    # Formatting
    ax.set_title(f"{city}", fontsize=14, fontweight="bold")
    ax.set_ylabel("Percent of Schools")
    ax.set_xlabel("HOLC Grade")
    ax.set_ylim(0, 110)
    ax.grid(False)

    # Legend only once (upper-right panel)
    if city != "Los Angeles":
        ax.get_legend().remove()

    # Build city summary table for later merging
    summary = counts.copy()
    for col in counts.columns:
        summary[f"{col}_pct"] = percents[col]
    summary["Total_Schools"] = counts.sum(axis=1)
    summary["City"] = city
    combined_tables.append(summary.reset_index())

# Add legend to top right panel
axes[1].legend(title="Number of Advanced STEM Courses", bbox_to_anchor=(1.3, 1))


plt.tight_layout()
plt.show()

# ---------- Combined summary table ----------
combined_df = pd.concat(combined_tables, ignore_index=True)

# Reorder columns cleanly
cols = ["City", "grade", "Total_Schools"]
for cp in sorted([0,1,2,3]):
    cols += [cp, f"{cp}_pct"]
combined_df = combined_df[cols]

print("\n======== Combined City-Level Summary Table ========")
print(combined_df.to_string(index=False))

# Optional: save
# combined_df.to_csv("Combined_City_STEM_Summary.csv", index=False)
# Out:
# ======== Combined City-Level Summary Table ========
#         City grade  Total_Schools  0     0_pct  1     1_pct  2     2_pct  3      3_pct
#      Chicago     B              5  0  0.000000  1 20.000000  1 20.000000  3  60.000000
#      Chicago     C             52 10 19.230769  7 13.461538 23 44.230769 12  23.076923
#      Chicago     D             54  7 12.962963 13 24.074074 24 44.444444 10  18.518519
#  Los Angeles     A              2  1 50.000000  0  0.000000  1 50.000000  0   0.000000
#  Los Angeles     B             13  4 30.769231  1  7.692308  5 38.461538  3  23.076923
#  Los Angeles     C             82 23 28.048780 16 19.512195 19 23.170732 24  29.268293
#  Los Angeles     D             66 13 19.696970 12 18.181818 22 33.333333 19  28.787879
# Philadelphia     A              1  0  0.000000  0  0.000000  0  0.000000  1 100.000000
# Philadelphia     B             16  4 25.000000  4 25.000000  5 31.250000  3  18.750000
# Philadelphia     C             16  2 12.500000  6 37.500000  2 12.500000  6  37.500000
# Philadelphia     D             32  6 18.750000  9 28.125000  9 28.125000  8  25.000000
#      Detroit     A              5  0  0.000000  0  0.000000  0  0.000000  5 100.000000
#      Detroit     B              1  0  0.000000  0  0.000000  0  0.000000  1 100.000000
#      Detroit     C             38 10 26.315789  9 23.684211 11 28.947368  8  21.052632
#      Detroit     D             41 14 34.146341 14 34.146341  8 19.512195  5  12.195122

# %% [markdown]
# ## Maps

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# ============================================================
# SETTINGS
# ============================================================

holc_colors = {
    "A": "#00b300",
    "B": "#c2e699",
    "C": "#fed976",
    "D": "#e31a1c"
}

stem_colors = {
    0: "lightgray",
    1: "orange",
    2: "blue",
    3: "black"
}

city_files = {
    "Chicago": "All_Classes_HS_Chicago.csv",
    "Los Angeles": "LA_Schools_With_AdvancedSTEM.csv",
    "Philadelphia": "Philly_Schools_With_AdvancedSTEM.csv",
    "Detroit": "Detroit_Schools_With_AdvancedSTEM.csv"
}

# ============================================================
# LOAD HOLC DATA (used for all cities)
# ============================================================

holc = gpd.read_file("mappinginequality.gpkg")
holc = holc.to_crs(epsg=4326)
holc["grade"] = holc["grade"].str.strip().str.upper()
holc = holc[holc["grade"].isin(["A", "B", "C", "D"])]

# ============================================================
# HELPER: Process city schools + filter HOLC polygons
# ============================================================

def load_city_data(city_name, filename):
    # Filter HOLC polygons for city
    holc_city = holc[holc["city"].str.contains(city_name, case=False, na=False)].copy()

    # Load school CSV
    df = pd.read_csv(filename)

    # Compute STEM count
    df["STEM_Count"] = (
        (df["Has_Calc"] == "Yes").astype(int) +
        (df["Has_CS"] == "Yes").astype(int) +
        (df["Has_Physics"] == "Yes").astype(int)
    )

    # Convert to GeoDataFrame
    geometry = [Point(xy) for xy in zip(df["LON"].astype(float), df["LAT"].astype(float))]
    gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

    return holc_city, gdf

# ============================================================
# PLOT 2×2 GRID OF HOLC MAPS
# ============================================================

fig, axes = plt.subplots(2, 2, figsize=(18, 16))
axes = axes.flatten()

for ax, (city, filename) in zip(axes, city_files.items()):

    holc_city, schools_city = load_city_data(city, filename)

    # ---- Plot HOLC polygons ----
    for grade, color in holc_colors.items():
        subset = holc_city[holc_city["grade"] == grade]
        if not subset.empty:
            subset.plot(ax=ax, color=color, alpha=0.35, edgecolor="black", linewidth=0.4)

    # ---- Plot schools by STEM count ----
    for count, color in stem_colors.items():
        subset = schools_city[schools_city["STEM_Count"] == count]
        if not subset.empty:
            subset.plot(
                ax=ax,
                color=color,
                markersize=18,
                edgecolor="black",
                linewidth=0.2
            )

    # ---- Formatting ----
    ax.set_title(f"{city}: STEM Course Availability by HOLC Zone", fontsize=14, fontweight="bold")
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.set_aspect('equal')

# ---- Legends: add ONE set on the final figure ----
holc_legend = [mpatches.Patch(color=color, label=f"Grade {grade}") for grade, color in holc_colors.items()]
stem_legend = [mpatches.Patch(color=color, label=f"{count} STEM Classes") for count, color in stem_colors.items()]

# Add legends outside the grid for cleanliness
fig.legend(handles=holc_legend, title="HOLC Grade", loc="upper center", ncol=4, fontsize=10)
fig.legend(handles=stem_legend, title="STEM Classes Offered", loc="lower center", ncol=4, fontsize=10)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])  # leave space for legends
plt.show()

# Optional save
# fig.savefig("HOLC_4City_STEM_Map.png", dpi=300)

# %% [markdown]
# ## Bar Charts w Error Bars

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

city_files = {
    "Chicago": "All_Classes_HS_Chicago.csv",
    "Los Angeles": "LA_Schools_With_AdvancedSTEM.csv",
    "Philadelphia": "Philly_Schools_With_AdvancedSTEM.csv",
    "Detroit": "Detroit_Schools_With_AdvancedSTEM.csv"
}

subjects = ["Num_Calc_Classes", "Num_CS_Classes", "Num_Physics_Classes"]

sns.set_style("whitegrid")

def load_city_df(filepath):
    df = pd.read_csv(filepath)

    df["grade"] = pd.Categorical(df["grade"], categories=["A","B","C","D"], ordered=True)

    df["Total_Adv_STEM"] = (
        df["Num_Calc_Classes"] +
        df["Num_CS_Classes"] +
        df["Num_Physics_Classes"]
    )

    plot_df = df.melt(
        id_vars="grade",
        value_vars=subjects,
        var_name="Subject",
        value_name="Classes"
    )

    return df, plot_df

# ------------------ FIXED Y-LIMIT FOR ALL CHARTS ------------------
FIXED_YMAX = 20

# ------------------------------------------------------------
# Generate the 2×2 grid with unified y-axis = 20
# ------------------------------------------------------------
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

for ax, (city, filepath) in zip(axes, city_files.items()):

    df, plot_df = load_city_df(filepath)

    sns.barplot(
        data=plot_df,
        x="grade",
        y="Classes",
        hue="Subject",
        estimator=np.mean,
        errorbar="se",
        ax=ax
    )

    ax.set_title(f"{city}", fontsize=14, fontweight="bold")
    ax.set_xlabel("HOLC Grade", fontsize=12)
    ax.set_ylabel("Average Number of Classes", fontsize=12)

    # ---- APPLY FIXED LIMIT ----
    ax.set_ylim(0, FIXED_YMAX)

    # Clean legends so only LA keeps it
    if city != "Los Angeles":
        ax.get_legend().remove()

axes[1].legend(
    title="Subject",
    bbox_to_anchor=(1.25, 1.02)
)

plt.tight_layout()
plt.show()
